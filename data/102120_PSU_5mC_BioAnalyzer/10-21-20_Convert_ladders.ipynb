# %%
import pandas as pd
import scipy as sp
from scipy.sparse import diags
import numpy as np
from numpy import linalg as LA
import sys

from os import path

import matplotlib.pyplot as plt

#importing seaborn for plotting
import seaborn as sns

#for plotting purposes
# %pylab inline
sns.set_style('ticks')
sns.set_context('paper')

# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"

import matplotlib as mpl

from scipy.signal import find_peaks

# mpl.rcParams
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['figure.figsize'] = [8, 16/3]
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/dosoonkim/anaconda3/lib/python3.7/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['number', 'f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### converting ladder to nts

# %%
data_dir = './raw_data/'
fig_dir = './plots/'
processed_dir = './processed_data/'

# %%
#list of filenames 
filenames = []

incomplete_ladder = ["Eukaryote Total RNA Nano_2020-12-10_07-47-43",
                     "Eukaryote Total RNA Nano_2020-12-10_08-35-37",
                     "Eukaryote Total RNA Nano_2020-12-10_08-43-35"]

with open("platenumber_filename.csv", 'r+') as f:
    for line in f.readlines()[1:]:
        filename = line.split(',')[1]
        filenames.append(filename)
        
for filename in filenames:
    
    """
    Plotting and identifying peaks from the ladder traces from BioAnalyzer.
    Must be done per chip/run, since ladders may elute at slightly different times per run.
    Generates plots that shows identified peaks.
    As of 12-10-2020, should identify 6 peaks.
    """
    
    ladder_dict = {}
    ladder_values = {}
    
    if filename in incomplete_ladder:
        peak_number = 5
    else:
        peak_number = 6

    ladder_df = pd.read_csv(data_dir+filename+'_Ladder.csv', skiprows=17)[:-1]
    ladder_time = np.array(ladder_df['Time'].astype(float))
    ladder_value = np.array(ladder_df['Value'].astype(float))

    peaks,_ = find_peaks(ladder_value, height=5, distance=30)
    ladder_dict = list(peaks[:peak_number])

    #plotting ladder trace + peak identification
    plot(ladder_time, ladder_value, label='ladder trace')
    plot(ladder_time[peaks], ladder_value[peaks], 'x', label='peaks', markersize=15)
    title('Ladder Peaks: '+filename, fontsize=16)
    legend(fontsize=14)
    xlabel('Time', fontsize=14)
    ylabel('FU', fontsize=14)
    xticks(fontsize=14)
    yticks(fontsize=14)
    tight_layout()
    
    #saving figure
    savefig(fig_dir+filename+'_ladder.png', dpi=300)
    clf()
    
    
    """
    Converting times (elution times from BioAnalyzer) to nucleotides using
    a 4th order polynomial fit
    """
    
    #returns the times when peaks occur, will serve as x on polynomial fit
    peak_times = ladder_time[ladder_dict]
    
    #ladder nucleotide sizes, will serve as y on polynomial fit
    if filename in incomplete_ladder:
        peak_fu = np.array([25, 500, 1000, 2000, 4000])
    else:
        peak_fu = np.array([25, 200, 500, 1000, 2000, 4000])
        
    #assert that the lengths of x and y match (cannot perform fit otherwise)
    assert (len(peak_times) == len(peak_fu))

    new_height = 5
    while (len(peak_times) < len(peak_fu)):
        new_height = new_height-0.1
        peaks,_ = find_peaks(ladder_value, height=new_height, distance=15)
        ladder_dict = list(peaks[:6])
        peak_times = ladder_time[ladder_dict]
        
    #fitting a 4th order polynomial to peaks/nucleotides
    ladder_fit = np.polyfit(x=peak_times, y = peak_fu, deg = 4)
    lf = np.poly1d(ladder_fit)
    ladder_nts = lf

    #print filename and ladder fit
    print('-----------')
    print('printing filename and ladder fit:')
    print(filename)
    print(lf)
    print('-----------')
    
    #plotting
    plot(peak_fu, lf(peak_times), 'o',label='calculated nts vs. ladder nts')
    plot(peak_fu, peak_fu,label='perfect correlation')
    ylabel('Calculated nts (from time)', fontsize=14)
    xlabel('Ladder nts', fontsize=14)
    yticks(fontsize=12)
    xticks(fontsize=12)
    title('Ladder polynomial fit: '+filename, fontsize=16)
    legend(fontsize=12)
    tight_layout()
    
    #saving figure
    savefig(fig_dir+'ladder_fit-'+filename+'.png', dpi=300)
    clf()

    
    """
    Applying fits to samples as well, per ladder
    """
    
    sample_numbers = np.arange(1,13)

    for number in sample_numbers:
        file = filename+'_Sample'+str(number)+".csv"
        print(file)
        if (path.exists(data_dir + file)):
            sample_df = pd.read_csv(data_dir + file, skiprows=17)[:-1]
            times = np.array(sample_df['Time'].astype(float))
            sample_df['Nucleotides'] = ladder_nts(times)
            sample_df.to_csv(processed_dir+'nts-'+ file)
        else:
            continue
# Out:
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_07-39-50
#            4           3         2
# 0.0009715 x + 0.01734 x - 2.729 x + 67.9 x - 568.8
# -----------
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_07-39-50_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_07-47-43
#           4         3       2
# -0.01357 x + 2.146 x - 117 x + 2725 x - 2.301e+04
# -----------
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_07-47-43_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_08-35-37
#          4         3         2
# -0.0134 x + 2.109 x - 114.3 x + 2648 x - 2.226e+04
# -----------
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_08-35-37_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_08-43-35
#           4         3         2
# -0.01023 x + 1.659 x - 90.89 x + 2118 x - 1.788e+04
# -----------
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_08-43-35_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_11-51-15
#             4          3         2
# -0.0001852 x + 0.1631 x - 9.432 x + 202.8 x - 1575
# -----------
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_11-51-15_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_11-57-22
#             4          3        2
# -0.0005751 x + 0.2142 x - 11.9 x + 254.9 x - 1978
# -----------
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_11-57-22_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_12-26-54
#            4          3         2
# -0.002265 x + 0.4544 x - 24.38 x + 534.5 x - 4259
# -----------
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample2.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample3.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample4.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample5.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample6.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample7.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample8.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample9.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample10.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample11.csv
# Eukaryote Total RNA Nano_2020-12-10_12-26-54_Sample12.csv
# -----------
# printing filename and ladder fit:
# Eukaryote Total RNA Nano_2020-12-10_12-35-05
#            4          3         2
# -0.001414 x + 0.3284 x - 17.71 x + 383.8 x - 3022
# -----------
# Eukaryote Total RNA Nano_2020-12-10_12-35-05_Sample1.csv
# Eukaryote Total RNA Nano_2020-12-10
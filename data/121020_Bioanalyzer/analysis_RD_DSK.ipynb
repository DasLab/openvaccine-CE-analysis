# %%
import numpy as np
data_dir = './processed_data/'
output_dir = './output/'
norm_peak = 0
pk_nt_bounds = np.array([(20, 30), (150,300), (820,1000)])
output_file = '121020_Bioanalyzer'

# %%
#quickly making sure output dir exists, if not make the directory
if os.path.exists(output_dir):
    pass
else:
    os.mkdir(output_dir)

import pandas as pd
import scipy as sp
from scipy.signal import find_peaks
import numpy as np
from os import path
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

#for plotting purposes
# %pylab inline
sns.set_style('ticks')
sns.set_context('paper')

# mpl.rcParams
mpl.rcParams['axes.labelsize'] = 14
mpl.rcParams['axes.titlesize'] = 16
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['legend.fontsize'] = 12
mpl.rcParams['figure.figsize'] = [8, 16/3]

#reading in samples and the corresponding filenames
samples_df = pd.read_csv('sample_nucleotide_filename.csv').dropna(axis=1)
all_sample_names = samples_df['Sample']

plates_df = pd.read_csv('platenumber_filename.csv').dropna(axis=1)
filenames_dict = dict(zip(plates_df['Plate_Number'],plates_df['File_Name']))

filenames = []
for filename, filenum in zip(samples_df['Plate'], samples_df['FileNumber']):
    name = filenames_dict[filename]
    name = 'nts-'+name+'_Sample'+str(filenum)+'.csv'
    filenames.append(name)

samples_df['filename'] = filenames

#appending data to dataframe
times = []
nts = []
fus = []
for row in samples_df.itertuples():
    signal_df = pd.read_csv(data_dir+row.filename)

    time = np.array(signal_df['Time'])
    fu = np.array(signal_df['Value'])
    nt = np.array(signal_df['Nucleotides'])
    
    times.append(time)
    nts.append(nt)
    fus.append(fu)

samples_df = samples_df.assign(nts = nts, times = times, fu = fus)

#now identifying peaks and areas
pkwidth_below = 1
pkwidth_above = 2

peak_idxs = []
peak_nts = []
widths_list = []
peak_area_list = []
background_area_list = []
peak_area_backsub_list = []
total_area_list = []
total_mRNA_list = []

for i, row in enumerate(samples_df.itertuples()):
    clip_len = int(len(row.nts/2.2))
    nts = row.nts[:clip_len]
    fu  = row.fu[:clip_len]
    times = row.times[:clip_len]
    
    #findings peaks per row
    peak_idx, properties = find_peaks(fu, distance=50, prominence=2.5, width=0.5)
    widths = properties['widths']

    #after finding peaks, filter them for only those that appear within bounds provided
    peak_idx_curated = []
    widths_curated = []
    num_pks = len(pk_nt_bounds)
    for q, idx in enumerate(peak_idx):
        for r in np.arange(num_pks):
            if (nts[idx]>pk_nt_bounds[r][0] and nts[idx]<pk_nt_bounds[r][1] and widths[q]<20):
                peak_idx_curated.append(idx)
                widths_curated.append(widths[q])

    # assume that the last peak is the peak of interest--if not found, then use w, peak_idx from before
    if nts[peak_idx_curated[-1]]>pk_nt_bounds[-1][0] and nts[peak_idx_curated[-1]]<pk_nt_bounds[-1][1]:
        pass
    else:
        peak_idx_curated = peak_idxs[-1]
        widths_curated = widths_list[-1]
    
    peak_nts.append(nts[peak_idx_curated])
    peak_idxs.append(peak_idx_curated)
    widths_list.append(widths_curated)

    num_peaks = len(peak_idx_curated)
    peak_area = np.zeros(num_peaks)
    background_area=np.zeros(num_peaks)
    for i in np.arange(num_peaks):
        min_idx = int(floor(peak_idx_curated[i]-pkwidth_below*widths_curated[i]))
        max_idx = int(ceil(peak_idx_curated[i]+pkwidth_above*widths_curated[i]))

        # straight up integration
        peak_area[i] = sum(fu[min_idx:max_idx])
        # trapezoidal for the background area
        background_area[i] = (max_idx-min_idx)*(fu[min_idx]+fu[max_idx])/2

    # calculating total background area
    total_min_nt = 100
    total_max_nt = 1000
    fp = np.arange(len(nts))
    total_min_idx = int(np.interp(total_min_nt, nts, fp))
    total_max_idx = int(np.interp(total_max_nt, nts, fp))
    total_area = sum(fu[total_min_idx:total_max_idx])
    total_mRNA = total_area - np.sum(peak_area[:-1]-background_area[:-1])

    peak_area_list.append(peak_area)
    background_area_list.append(background_area)
    peak_area_backsub_list.append(peak_area-background_area)
    total_area_list.append(total_area)
    total_mRNA_list.append(total_mRNA)

samples_df = samples_df.assign(peak_index = peak_idxs, peak_nts = peak_nts, peak_widths = widths_list, peak_area = peak_area_list, background_area = background_area_list, peak_area_backsub = peak_area_backsub_list, total_area = total_area_list, total_mRNA = total_mRNA_list)


#now moving onto fits!
from scipy import optimize
#normalizing for exponential curve fitting, will need to do it by each sample
#let's first iterate through by sample
all_samples = samples_df['Sample']
seen = set()
unique_samples = [x for x in all_samples if not (x in seen or seen.add(x))]

sample_df_list = []
sample_fit_list = []
for sample in unique_samples:
    print(sample)
    sample_fit_dict = {}
    sample_df = samples_df[samples_df['Sample']==sample]
    peak_area_backsub = np.array(sample_df['peak_area_backsub'].to_list())
    total_mRNA = sample_df['total_mRNA']
    if norm_peak == 0:
        frac_intact = np.array(peak_area_backsub[:,-1]/total_mRNA)
    elif norm_peak<0:
        frac_intact = np.array(peak_area_backsub[:,-1])
    elif norm_peak>0:
        frac_intact = np.array(peak_area_backsub[:,-1]/peak_area_backsub[:,norm_peak-1])
    frac_norm = (frac_intact/frac_intact[0]).flatten()

    sample_df['fraction_intact'] = frac_intact
    sample_df['fraction_norm'] = frac_norm

    sample_df_list.append(sample_df)

    expfit = lambda p,t,y: (abs(np.exp(-1*p*t)-y)).sum()
    p0=1
    times = sample_df['Timepoint'].to_numpy().flatten()
    print(times)
    print(frac_norm)
    p = optimize.fmin(func=expfit, x0=p0, args=(times,frac_norm))
    print(p)

    n_bootstrap = 1000
    kdeg_fits = []
    for i in np.arange(n_bootstrap):
        bootstrap_inds = np.random.choice(a=len(times), size=len(times))
        fit_t = times[bootstrap_inds]
        fit_frac = frac_norm[bootstrap_inds]
        p = optimize.fmin(func=expfit, x0=p0, args=(fit_t,fit_frac))
        kdeg_fits.append(float(p))
    kdeg_mean = np.mean(kdeg_fits)
    kdeg_err = np.std(kdeg_fits)

    sample_fit_dict['kdeg_fits'] = kdeg_fits
    sample_fit_dict['kdeg'] = kdeg_mean
    sample_fit_dict['kdeg_err'] = kdeg_err
    sample_fit_dict['sample'] = sample

    sample_fit_list.append(sample_fit_dict) 

    sample_fit_df = pd.DataFrame(sample_fit_list)
    sample_fit_df.to_csv(output_file+'_expfits.csv')

    final_df = pd.concat(sample_df_list)
    final_df.to_csv(output_dir+output_file+'_summary.csv')
# Out:
# on terminated successfully.
#          Current function value: 0.293994
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.449135
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.657586
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.347766
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.260488
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.187915
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.413568
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.363503
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.335453
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.067609
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.240036
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.337929
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.407001
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.321863
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.356592
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.542292
#          Iterations: 17
#          Function evaluations: 35
# Optimization terminated successfully.
#          Current function value: 0.353373
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.265513
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.463000
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.449671
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.511360
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.375157
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.412405
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.357351
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.352647
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.258670
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.522374
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.421860
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.333884
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.528497
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.497831
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.385803
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.331927
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.549488
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.688322
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.457437
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.128897
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.298900
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.228508
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.185421
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.174438
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.616139
#          Iterations: 18
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.479565
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.278228
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.305953
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.243530
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.404913
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.400177
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.195227
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.379238
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.274257
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.329733
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.351675
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.489188
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.707100
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.349310
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.451054
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.343734
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.331590
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.283473
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.134474
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.200736
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.189704
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.427054
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.399209
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.480302
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.305632
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.385689
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.391137
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.343102
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.362155
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.590061
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.569577
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.255797
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.758776
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.303933
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.701698
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.310114
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.376846
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.656292
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.180904
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.272634
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.299417
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.618351
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.286598
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.429953
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.262845
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.668466
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.590298
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.191372
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.183726
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.401843
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.527600
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.446313
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.317287
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.448572
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.180582
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.351002
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.356251
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.295581
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.286407
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.216416
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.200905
#          Iterations: 19
#          Function evaluations: 38
# Optimization terminated successfully.
#          Current function value: 0.393816
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.508279
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.348425
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.451881
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.510976
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.426991
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.419178
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.355514
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.483514
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.160129
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.404477
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.236416
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.558318
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.437915
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.323281
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.606382
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.428052
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.318993
#          Iterations: 18
#          Function evaluations: 37
# Optimization terminated successfully.
#          Current function value: 0.400178
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.523579
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.768633
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.366368
#          Iterations: 19
#          Function evaluations: 39
# Optimization terminated successfully.
#          Current function value: 0.423532
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.259502
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.265739
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.450406
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.463111
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.347686
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.580146
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.267520
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.387667
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.375362
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.517335
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.387849
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.188990
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: 0.370494
#          Iterations: 16
#          Function evaluations: 32
# Optimization terminated successfully.
#          Current function value: 0.649530
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.256781
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: 0.576712
#          Iterations: 17
#          Function evaluations: 34
# Optimization terminated successfully.
#          Current function value: 0.586021
#          Iterations: 21
#          Function evaluations: 42
# Optimization terminated successfully.
#          Current function value: 0.368398
#          Iterations: 20
#          Function evaluations: 40
# Optimization terminated successfully.
#          Current function value: 0.287012
#          Iterations: 15
#          Function evaluations: 30
